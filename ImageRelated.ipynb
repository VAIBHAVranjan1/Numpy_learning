# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
for i in range(1, 6):
    loaded_image = np.load(f'images/image_{i}.npy')  # Correct relative path
    plt.figure()
    plt.imshow(loaded_image)
    plt.title(f'Image {i}')
    plt.axis('off')
